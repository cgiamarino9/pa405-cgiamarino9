# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Week-2:-Python-and-Metro" data-toc-modified-id="Week-2:-Python-and-Metro-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Week 2: Python and Metro</a></span><ul class="toc-item"><li><span><a href="#A-quick-geopandas-teaser" data-toc-modified-id="A-quick-geopandas-teaser-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>A quick geopandas teaser</a></span></li><li><span><a href="#Pandas-Data-Types" data-toc-modified-id="Pandas-Data-Types-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Pandas Data Types</a></span></li><li><span><a href="#Data-exploration" data-toc-modified-id="Data-exploration-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Data exploration</a></span><ul class="toc-item"><li><span><a href="#Counting-unique-values-in-a-column" data-toc-modified-id="Counting-unique-values-in-a-column-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Counting unique values in a column</a></span></li><li><span><a href="#Rename-columns" data-toc-modified-id="Rename-columns-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Rename columns</a></span></li><li><span><a href="#A-quick-bar-plot" data-toc-modified-id="A-quick-bar-plot-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>A quick bar plot</a></span></li><li><span><a href="#Trimming-the-data" data-toc-modified-id="Trimming-the-data-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Trimming the data</a></span></li><li><span><a href="#Subsetting/querying/filtering-the-data" data-toc-modified-id="Subsetting/querying/filtering-the-data-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>Subsetting/querying/filtering the data</a></span></li></ul></li><li><span><a href="#Plotting" data-toc-modified-id="Plotting-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Plotting</a></span><ul class="toc-item"><li><span><a href="#A-prettier-plot" data-toc-modified-id="A-prettier-plot-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>A prettier plot</a></span></li></ul></li><li><span><a href="#Mapping-with-folium" data-toc-modified-id="Mapping-with-folium-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Mapping with folium</a></span><ul class="toc-item"><li><span><a href="#Get-average-lat/lon's" data-toc-modified-id="Get-average-lat/lon's-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Get average lat/lon's</a></span></li><li><span><a href="#Folium-map-with-arguments" data-toc-modified-id="Folium-map-with-arguments-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Folium map with arguments</a></span></li><li><span><a href="#Adding-point-markers" data-toc-modified-id="Adding-point-markers-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Adding point markers</a></span></li><li><span><a href="#Color-code-markers" data-toc-modified-id="Color-code-markers-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>Color code markers</a></span></li><li><span><a href="#Find-unique-values-in-a-column" data-toc-modified-id="Find-unique-values-in-a-column-1.5.5"><span class="toc-item-num">1.5.5&nbsp;&nbsp;</span>Find unique values in a column</a></span></li><li><span><a href="#Update-column-based-on-a-query-on-another-column" data-toc-modified-id="Update-column-based-on-a-query-on-another-column-1.5.6"><span class="toc-item-num">1.5.6&nbsp;&nbsp;</span>Update column based on a query on another column</a></span></li><li><span><a href="#Saving-your-folium-map-as-an-HTML-file" data-toc-modified-id="Saving-your-folium-map-as-an-HTML-file-1.5.7"><span class="toc-item-num">1.5.7&nbsp;&nbsp;</span>Saving your folium map as an HTML file</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <div class="alert alert-danger">
#
# Take notice:
# <ul>
#     <li>This class will be recorded</li>
# </ul>
#
# </div>

# %% [markdown]
# # Week 2: Python and Metro

# %% [markdown]
# ## A quick geopandas teaser
# Following our Python bootcamp last week (was it boring? exhilerating? a bit of both?), let's put that programming knowledge into action, using and creating data that reflects a real urban situation.
#
# We start by importing a new module `geopandas`. This is a pretty high level geospatial library, widely used by spatial data scientists all over the world. Don't worry about it too much for now, but know that it allows us to import a variety of spatial data formats, and plot them on a map.
#
# * [geopandas documentation](https://geopandas.readthedocs.io/en/latest/gallery/index.html)

# %%
# check which libraries are installed
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# affine                    2.4.0
# aiohappyeyeballs          2.4.0
# aiohttp                   3.10.5
# aiosignal                 1.3.1
# alembic                   1.13.2
# altair                    5.4.1
# annotated-types           0.7.0
# anyio                     4.4.0
# archspec                  0.2.3
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async_generator           1.10
# async-lru                 2.0.4
# attrs                     24.2.0
# Babel                     2.14.0
# bash_kernel               0.10.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# blinker                   1.8.2
# bokeh                     3.5.2
# boltons                   24.0.0
# Bottleneck                1.4.0
# branca                    0.8.1
# Brotli                    1.1.0
# cached-property           1.5.2
# certifi                   2024.12.14
# certipy                   0.1.3
# cffi                      1.17.1
# charset-normalizer        3.3.2
# click                     8.1.7
# click-plugins             1.1.1
# cligj                     0.7.2
# cloudpickle               3.0.0
# colorama                  0.4.6
# comm                      0.2.2
# conda                     24.7.1
# conda-libmamba-solver     24.7.0
# conda-package-handling    2.3.0
# conda_package_streaming   0.10.0
# contextily                1.6.2
# contourpy                 1.3.0
# cryptography              43.0.1
# cycler                    0.12.1
# Cython                    3.0.11
# cytoolz                   0.12.3
# dash                      2.18.2
# dash-core-components      2.0.0
# dash-html-components      2.0.0
# dash-table                5.0.0
# dask                      2024.8.2
# dask-expr                 1.1.13
# debugpy                   1.8.5
# decorator                 5.1.1
# defusedxml                0.7.1
# dill                      0.3.8
# distributed               2024.8.2
# distro                    1.9.0
# entrypoints               0.4
# esda                      2.6.0
# et-xmlfile                1.1.0
# exceptiongroup            1.2.2
# executing                 2.1.0
# fastjsonschema            2.20.0
# filetype                  1.2.0
# Flask                     3.0.3
# folium                    0.19.4
# fonttools                 4.53.1
# fqdn                      1.5.1
# frozendict                2.4.4
# frozenlist                1.4.1
# fsspec                    2024.9.0
# geographiclib             2.0
# geopandas                 1.0.1
# geopy                     2.4.1
# giddy                     2.3.6
# gitdb                     4.0.11
# GitPython                 3.1.43
# gmpy2                     2.1.5
# greenlet                  3.0.3
# h11                       0.14.0
# h2                        4.1.0
# h5py                      3.11.0
# hpack                     4.0.0
# httpcore                  1.0.5
# httpx                     0.27.2
# hyperframe                6.0.1
# idna                      3.8
# imagecodecs               2024.6.1
# imageio                   2.35.1
# importlib_metadata        8.4.0
# importlib_resources       6.4.4
# ipykernel                 6.29.5
# ipympl                    0.9.4
# ipython                   8.27.0
# ipython_genutils          0.2.0
# ipywidgets                8.1.5
# isoduration               20.11.0
# itsdangerous              2.2.0
# jedi                      0.19.1
# Jinja2                    3.1.4
# joblib                    1.4.2
# json5                     0.9.25
# jsonpatch                 1.33
# jsonpointer               3.0.0
# jsonschema                4.23.0
# jsonschema-specifications 2023.12.1
# jupyter_client            8.6.2
# jupyter_core              5.7.2
# jupyter-events            0.10.0
# jupyter-lsp               2.2.5
# jupyter-pluto-proxy       0.1.2
# jupyter-resource-usage    1.1.0
# jupyter-rsession-proxy    2.2.1
# jupyter_server            2.14.2
# jupyter-server-mathjax    0.2.6
# jupyter_server_proxy      4.4.0
# jupyter_server_terminals  0.5.3
# jupyter-shiny-proxy       1.3
# jupyterhub                5.1.0
# jupyterlab                4.2.5
# jupyterlab_git            0.50.1
# jupyterlab-mathjax3       4.3.0
# jupyterlab_pygments       0.3.0
# jupyterlab_rise           0.43.1
# jupyterlab_server         2.27.3
# jupyterlab_widgets        3.0.13
# kiwisolver                1.4.7
# lazy_loader               0.4
# libmambapy                1.5.9
# libpysal                  4.12.1
# llvmlite                  0.43.0
# locket                    1.0.0
# lz4                       4.3.3
# Mako                      1.3.5
# mamba                     1.5.9
# mapclassify               2.8.1
# MarkupSafe                2.1.5
# matplotlib                3.9.2
# matplotlib-inline         0.1.7
# menuinst                  2.1.2
# mercantile                1.2.1
# mistune                   3.0.2
# mpmath                    1.3.0
# msgpack                   1.0.8
# multidict                 6.0.5
# munkres                   1.1.4
# narwhals                  1.6.3
# nbclassic                 1.1.0
# nbclient                  0.10.0
# nbconvert                 7.16.4
# nbdime                    4.0.2
# nbformat                  5.10.4
# nbgitpuller               1.2.1
# nest_asyncio              1.6.0
# networkx                  3.3
# notebook                  7.2.2
# notebook_shim             0.2.4
# numba                     0.60.0
# numexpr                   2.10.0
# numpy                     2.0.2
# oauthlib                  3.2.2
# openpyxl                  3.1.5
# osmnx                     2.0.1
# overrides                 7.7.0
# packaging                 24.1
# pamela                    1.2.0
# pandas                    2.2.2
# pandocfilters             1.5.0
# parso                     0.8.4
# partd                     1.4.2
# patsy                     0.5.6
# pexpect                   4.9.0
# pickleshare               0.7.5
# pillow                    10.4.0
# pip                       24.2
# pkgutil_resolve_name      1.3.10
# platformdirs              4.3.2
# plotly                    5.24.1
# pluggy                    1.5.0
# prometheus_client         0.20.0
# prompt_toolkit            3.0.47
# protobuf                  4.25.3
# psutil                    5.9.8
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# py-cpuinfo                9.0.0
# pyarrow                   17.0.0
# pyarrow-hotfix            0.6
# pycosat                   0.6.6
# pycparser                 2.22
# pycurl                    7.45.3
# pydantic                  2.8.2
# pydantic_core             2.20.1
# Pygments                  2.18.0
# PyJWT                     2.9.0
# pyogrio                   0.10.0
# pyOpenSSL                 24.2.1
# pyparsing                 3.1.4
# pyproj                    3.7.0
# PySocks                   1.7.1
# python-dateutil           2.9.0
# python-json-logger        2.0.7
# pytz                      2024.1
# PyWavelets                1.7.0
# PyYAML                    6.0.2
# pyzmq                     26.2.0
# quantecon                 0.7.2
# rasterio                  1.4.1
# referencing               0.35.1
# requests                  2.32.3
# retrying                  1.3.4
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rio-vrt                   0.3.1
# rise                      5.7.1
# rpds-py                   0.20.0
# rpy2                      3.5.11
# ruamel.yaml               0.18.6
# ruamel.yaml.clib          0.2.8
# scikit-image              0.24.0
# scikit-learn              1.5.1
# scipy                     1.14.1
# seaborn                   0.13.2
# Send2Trash                1.8.3
# setuptools                73.0.1
# shapely                   2.0.6
# simpervisor               1.0.0
# simplegeneric             0.8.1
# six                       1.16.0
# smmap                     5.0.0
# sniffio                   1.3.1
# snuggs                    1.4.7
# sodapy                    2.2.0
# sortedcontainers          2.4.0
# soupsieve                 2.5
# splot                     1.1.7
# spreg                     1.8.1
# SQLAlchemy                2.0.34
# stack-data                0.6.2
# statsmodels               0.14.2
# sympy                     1.13.2
# tables                    3.10.1
# tblib                     3.0.0
# tenacity                  9.0.0
# terminado                 0.18.1
# threadpoolctl             3.5.0
# tifffile                  2024.8.30
# tinycss2                  1.3.0
# tomli                     2.0.1
# toolz                     0.12.1
# tornado                   6.4.1
# tqdm                      4.66.5
# traitlets                 5.14.3
# truststore                0.9.2
# types-python-dateutil     2.9.0.20240906
# typing_extensions         4.12.2
# typing-utils              0.1.0
# tzdata                    2024.1
# tzlocal                   5.2
# uri-template              1.3.0
# urllib3                   2.2.2
# wcwidth                   0.2.13
# webcolors                 24.8.0
# webencodings              0.5.1
# websocket-client          1.8.0
# Werkzeug                  3.0.6
# wheel                     0.44.0
# widgetsnbextension        4.0.13
# xlrd                      2.0.1
# xyzservices               2024.9.0
# yarl                      1.10.0
# zict                      3.0.0
# zipp                      3.20.1
# zstandard                 0.23.0

# %%
# pip install allows us to import third party libraries to anaconda
# !pip install numpy pandas geopandas matplotlib folium
# Out:
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (2.0.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: geopandas in /opt/conda/lib/python3.11/site-packages (1.0.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: folium in /opt/conda/lib/python3.11/site-packages (0.19.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/conda/lib/python3.11/site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from geopandas) (24.1)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.11/site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: branca>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /opt/conda/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from pyogrio>=0.7.2->geopandas) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->folium) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->folium) (2.2.2)

# %%
# imorting libraries for spatial data analysis 
import pandas as pd # data table analyses
import geopandas as gpd # spatial data analyses
import matplotlib.pyplot as plt # static charts and map visualization

# %% [markdown]
# Next, we import some data. In this case, it is a [shapefile](https://desktop.arcgis.com/en/arcmap/latest/manage-data/shapefiles/what-is-a-shapefile.htm) downloaded from the [LA Metro's Developer web portal](https://developer.metro.net/gis-data/). Notice that we are using *relative* paths to point to where the data is located in.
#
# * [documentation on geopandas function `read_file`](https://geopandas.readthedocs.io/en/latest/docs/user_guide/io.html)

# %%
# read and add shapefile to notebook
metro = gpd.read_file('data/metroRail_2023.zip')

# %% [markdown]
# <div class="alert alert-info">
#
# Note that the reason we use `geopandas` instead of `pandas` (other than the fact that we love maps) is that `pandas` cannot read shapefiles, whereas `geopandas` can.
#
# </div>

# %%
# what's the data type?
type(metro)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# what does the data look like? 
metro.head()
# Out:
#   LINE                          STATION        LAT         LON  \
# 0    B          North Hollywood Station  34.168504 -118.376808
# 1    B  Universal / Studio City Station  34.140002 -118.362699
# 2    B     Hollywood / Highland Station  34.101547 -118.338549
# 3    B         Hollywood / Vine Station  34.101630 -118.325180
# 4    B      Hollywood / Western Station  34.101737 -118.308117
#
#                       geometry
# 0   POINT (-118.37681 34.1685)
# 1      POINT (-118.3627 34.14)
# 2  POINT (-118.33855 34.10155)
# 3  POINT (-118.32518 34.10163)
# 4  POINT (-118.30812 34.10174)

# %% [markdown]
# Ah! Surprise, surprise. Welcome to your first look at a pandas dataframe. We will cover dataframes more extensively in later sessions, but know that a python dataframe is like an excel spreadsheet.

# %% [markdown]
# The `head()` command shows us the first 5 rows of the dataframe. You can also use `tail()` and `sample()`. Try these commands in the cells below:

# %%
# try tail()
metro.tail(1)

# %%
# try sample()
metro.sample(2)

# %% [markdown]
# ## Pandas Data Types
#
# Let's look at the data types for each column. You can collectively get all the datatypes for each column in a dataframe using the `dtypes` command.

# %%
metro.dtypes
# Out:
# LINE          object
# STATION       object
# LAT          float64
# LON          float64
# geometry    geometry
# dtype: object

# %% [markdown]
# But there is better command that will get you more info. Yes, the `info` command.

# %%
# dataframe info
metro.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LINE      112 non-null    object
#  1   STATION   112 non-null    object
#  2   LAT       112 non-null    float64
#  3   LON       112 non-null    float64
#  4   geometry  112 non-null    geometry
# dtypes: float64(2), geometry(1), object(2)
# memory usage: 4.5+ KB

# %% [markdown]
# Wait. That looks different from what we have worked on! As it turns out, pandas datatypes are slightly different from the raw python datatypes. Check out the table below:

# %% [markdown]
# <table class="table table-striped">
#   <thead>
#     <tr>
#       <th>Pandas Type</th>
#       <th>Native Python Type</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>object</td>
#       <td>string</td>
#       <td>The most general dtype. Will be assigned to your column if column has mixed types (numbers and strings).</td>
#     </tr>
#     <tr>
#       <td>int64</td>
#       <td>int</td>
#       <td>Numeric characters. 64 refers to the memory allocated to hold this character.</td>
#     </tr>
#     <tr>
#       <td>float64</td>
#       <td>float</td>
#       <td>Numeric characters with decimals. If a column contains numbers and NaNs (see below), pandas will default to float64, in case your missing value has a decimal.</td>
#     </tr>
#     <tr>
#       <td>datetime64, timedelta[ns]</td>
#       <td>N/A (but see the <a href="http://doc.python.org/2/library/datetime.html">datetime</a> module in Python’s standard library)</td>
#       <td>Values meant to hold time data. Look into these for time series experiments.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Data exploration
#
# Part of data exploration is learning what is in your data. How many rows are there? What are the columns? How many rows represent a particular slice of the data?

# %%
# how many rows and columns?
metro.shape
# Out:
# (112, 5)

# %%
# what are the columns?
metro.columns.to_list()
# Out:
# ['LINE', 'STATION', 'LAT', 'LON', 'geometry']

# %% [markdown]
# ### Counting unique values in a column
#
# First, learn how to get values for a single column.

# %%
# single column
metro['LINE Letter'].sample(20)
# Out:
# 33       K
# 2        B
# 11     B/D
# 104      A
# 61       E
# 43       E
# 4        B
# 77       A
# 0        B
# 85       A
# 26       C
# 22       C
# 42       E
# 108      A
# 23       C
# 52       E
# 69       A
# 40       E
# 66       E
# 25       C
# Name: LINE, dtype: object

# %%
# another way
metro.LINE.sample(5)
# Out:
# 52       E
# 13     B/D
# 100      A
# 21       C
# 37       K
# Name: LINE, dtype: object

# %% [markdown]
# <div class="alert alert-info">
# What are situations when one method is necessary over the other? (i.e. metro['LINE'] vs metro.LINE)
# </div>

# %% [markdown]
# This returns what is called a python series, a one dimensional array.

# %% [markdown]
# But what if you want to know how many stations there are for each line?

# %%
metro['LINE'].value_counts()
# Out:
# LINE
# A      39
# E      34
# C      14
# K       9
# B       8
# B/D     6
# D       2
# Name: count, dtype: int64

# %%
# save it as a variable
line_count = metro['LINE'].value_counts()
line_count
# Out:
# LINE
# A      39
# E      34
# C      14
# K       9
# B       8
# B/D     6
# D       2
# Name: count, dtype: int64

# %%
# what data type is line_count?
type(line_count)
# Out:
# pandas.core.series.Series

# %%
# let's convert the series into a dataframe
line_count = line_count.reset_index()
line_count
# Out:
#   LINE  count
# 0    A     39
# 1    E     34
# 2    C     14
# 3    K      9
# 4    B      8
# 5  B/D      6
# 6    D      2

# %%
# what is the type of this variable?
type(line_count)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Rename columns

# %%
# current columns as a list
line_count.columns.to_list()
# Out:
# ['LINE', 'count']

# %% [markdown]
# To rename columns, simply give it a list of column names

# %%
line_count.columns = ['LA Metro Station', 'Number of Stations per Line']

# %%
line_count
# Out:
#   LA Metro Station  Number of Stations per Line
# 0                A                           39
# 1                E                           34
# 2                C                           14
# 3                K                            9
# 4                B                            8
# 5              B/D                            6
# 6                D                            2

# %% [markdown]
# ### A quick bar plot

# %% [markdown]
# * [pandas plot](https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/04_plotting.html#min-tut-04-plotting)

# %%
line_count.plot()
# Out:
# <Axes: >

# %%
# give it additional arguments
line_count.plot.bar(x = 'LA Metro Station', y = 'Number of Stations per Line', title = 'Number of stops per metro line')
# Out:
# <Axes: title={'center': 'Number of stops per metro line'}, xlabel='LA Metro Station'>

# %% [markdown]
# ### Trimming the data
# Oftentimes, we import data and it has too many columns. It is always good practice to eliminate those rows that you are sure you will not use, and keep your data "clean" and "mean."

# %%
# output the original data's info
metro.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LINE      112 non-null    object
#  1   STATION   112 non-null    object
#  2   LAT       112 non-null    float64
#  3   LON       112 non-null    float64
#  4   geometry  112 non-null    geometry
# dtypes: float64(2), geometry(1), object(2)
# memory usage: 4.5+ KB

# %%
# show a dataframe with a subset of columns
metro[['LINE','STATION','LAT','LON','geometry']]
# Out:
#     LINE                               STATION        LAT         LON  \
# 0      B               North Hollywood Station  34.168504 -118.376808
# 1      B       Universal / Studio City Station  34.140002 -118.362699
# 2      B          Hollywood / Highland Station  34.101547 -118.338549
# 3      B              Hollywood / Vine Station  34.101630 -118.325180
# 4      B           Hollywood / Western Station  34.101737 -118.308117
# ..   ...                                   ...        ...         ...
# 107    A                Azusa Downtown Station  34.135863 -117.906631
# 108    A          APU / Citrus College Station  34.136814 -117.891636
# 109    E  Grand Ave Arts / Bunker Hill Station  34.054724 -118.251531
# 110    E             Historic Broadway Station  34.052156 -118.246321
# 111    E  Little Tokyo / Arts District Station  34.048845 -118.238757
#
#                         geometry
# 0     POINT (-118.37681 34.1685)
# 1        POINT (-118.3627 34.14)
# 2    POINT (-118.33855 34.10155)
# 3    POINT (-118.32518 34.10163)
# 4    POINT (-118.30812 34.10174)
# ..                           ...
# 107  POINT (-117.90663 34.13586)
# 108  POINT (-117.89164 34.13681)
# 109  POINT (-118.25153 34.05472)
# 110  POINT (-118.24632 34.05216)
# 111  POINT (-118.23876 34.04884)
#
# [112 rows x 5 columns]

# %% [markdown]
# Wait, why the double square brackets? `[[...]]`
#
# The reason for this is that we are feeding the dataframe a list of column names. Another way to do the same thing would be:

# %%
# list of desired column names
desired_columns = ['LINE','STATION','geometry']

# subset based on desired columns
metro[desired_columns].sample(5)
# Out:
#    LINE                                            STATION  \
# 21    C                         Hawthorne / Lennox Station
# 10  B/D  7th St / Metro Center Station - Metro Red & Pu...
# 52    E                     Westwood / Rancho Park Station
# 15    D                         Wilshire / Western Station
# 28    C                              Lakewood Blvd Station
#
#                        geometry
# 21   POINT (-118.3516 33.93341)
# 10  POINT (-118.25868 34.04863)
# 52  POINT (-118.42458 34.03682)
# 15  POINT (-118.30876 34.06169)
# 28   POINT (-118.1406 33.91307)

# %% [markdown]
# If you now print the dataframe, what happens?

# %%
metro.head()
# Out:
#   LINE                          STATION        LAT         LON  \
# 0    B          North Hollywood Station  34.168504 -118.376808
# 1    B  Universal / Studio City Station  34.140002 -118.362699
# 2    B     Hollywood / Highland Station  34.101547 -118.338549
# 3    B         Hollywood / Vine Station  34.101630 -118.325180
# 4    B      Hollywood / Western Station  34.101737 -118.308117
#
#                       geometry
# 0   POINT (-118.37681 34.1685)
# 1      POINT (-118.3627 34.14)
# 2  POINT (-118.33855 34.10155)
# 3  POINT (-118.32518 34.10163)
# 4  POINT (-118.30812 34.10174)

# %% [markdown]
# What happened? Why has the dataframe reverted to the original data?

# %% [markdown]
# That's right. In order to preserve your new dataframe, you have to **declare** it as a new variable. And finally, whenever you make a copy of a dataframe, it is **highly recommended** to add the `.copy()` command at the end:

# %%
# set a new geodataframe based on a subset of column names from the list and create a copy
metro_trimmed = metro[desired_columns].copy()
metro_trimmed
# Out:
#     LINE                               STATION                     geometry
# 0      B               North Hollywood Station   POINT (-118.37681 34.1685)
# 1      B       Universal / Studio City Station      POINT (-118.3627 34.14)
# 2      B          Hollywood / Highland Station  POINT (-118.33855 34.10155)
# 3      B              Hollywood / Vine Station  POINT (-118.32518 34.10163)
# 4      B           Hollywood / Western Station  POINT (-118.30812 34.10174)
# ..   ...                                   ...                          ...
# 107    A                Azusa Downtown Station  POINT (-117.90663 34.13586)
# 108    A          APU / Citrus College Station  POINT (-117.89164 34.13681)
# 109    E  Grand Ave Arts / Bunker Hill Station  POINT (-118.25153 34.05472)
# 110    E             Historic Broadway Station  POINT (-118.24632 34.05216)
# 111    E  Little Tokyo / Arts District Station  POINT (-118.23876 34.04884)
#
# [112 rows x 3 columns]

# %% [markdown]
# ### Subsetting/querying/filtering the data
#
# What if you only want to see a subset of the data? Or create a new table based on a query?

# %%
metroE = metro_trimmed[metro_trimmed.LINE == 'E'].copy()
metro_trimmed.sample(20)
# Out:
#     LINE                                          STATION  \
# 50     E                              Culver City Station
# 29     C                                  Norwalk Station
# 46     E                   Expo / Crenshaw E-Line Station
# 49     E                   La Cienega / Jefferson Station
# 63     E           Mariachi Plaza / Boyle Heights Station
# 25     C                                   Avalon Station
# 51     E                                    Palms Station
# 18     C                               El Segundo Station
# 57     E                    Downtown Santa Monica Station
# 109    E             Grand Ave Arts / Bunker Hill Station
# 17     C                                  Douglas Station
# 85     A                            Grand / LATTC Station
# 39     E                                     Pico Station
# 68     A                      Downtown Long Beach Station
# 36     K                             Leimert Park Station
# 91     A                                Chinatown Station
# 7      B                        Vermont / Beverly Station
# 77     A  Willowbrook - Rosa Parks Station - Metro A-Line
# 100    A                                     Lake Station
# 74     A                                  Del Amo Station
#
#                         geometry
# 50    POINT (-118.38899 34.0279)
# 29   POINT (-118.10472 33.91403)
# 46   POINT (-118.33508 34.02253)
# 49   POINT (-118.37212 34.02636)
# 63   POINT (-118.21965 34.04722)
# 25   POINT (-118.26522 33.92746)
# 51   POINT (-118.40426 34.02932)
# 18   POINT (-118.38654 33.91606)
# 57   POINT (-118.49138 34.01401)
# 109  POINT (-118.25153 34.05472)
# 17    POINT (-118.38311 33.9053)
# 85   POINT (-118.26933 34.03316)
# 39   POINT (-118.26612 34.04074)
# 68   POINT (-118.19292 33.76807)
# 36   POINT (-118.33202 34.00391)
# 91   POINT (-118.23584 34.06386)
# 7    POINT (-118.29169 34.07653)
# 77   POINT (-118.23756 33.92805)
# 100  POINT (-118.13139 34.15181)
# 74   POINT (-118.21102 33.84822)

# %% [markdown]
# Another way using `.loc`
# - https://www.w3resource.com/pandas/dataframe/dataframe-loc.php

# %%
# another way .loc
metro_trimmed.loc[metro_trimmed['LINE'] == 'B']
# Out:
#   LINE                          STATION                     geometry
# 0    B          North Hollywood Station   POINT (-118.37681 34.1685)
# 1    B  Universal / Studio City Station      POINT (-118.3627 34.14)
# 2    B     Hollywood / Highland Station  POINT (-118.33855 34.10155)
# 3    B         Hollywood / Vine Station  POINT (-118.32518 34.10163)
# 4    B      Hollywood / Western Station  POINT (-118.30812 34.10174)
# 5    B         Vermont / Sunset Station  POINT (-118.29176 34.09771)
# 6    B   Vermont / Santa Monica Station  POINT (-118.29173 34.08991)
# 7    B        Vermont / Beverly Station  POINT (-118.29169 34.07653)

# %%
# another way .query
metro_trimmed.query("LINE == 'E'")
# Out:
#     LINE                                            STATION  \
# 39     E                                       Pico Station
# 40     E  7th Street / Metro Center Station - Metro A & ...
# 41     E                    LATTC / Ortho Institute Station
# 42     E                            Jefferson / USC Station
# 43     E                            Expo Park / USC Station
# 44     E                             Expo / Vermont Station
# 45     E                             Expo / Western Station
# 46     E                     Expo / Crenshaw E-Line Station
# 47     E                                   Farmdale Station
# 48     E             Expo / La Brea / Ethel Bradley Station
# 49     E                     La Cienega / Jefferson Station
# 50     E                                Culver City Station
# 51     E                                      Palms Station
# 52     E                     Westwood / Rancho Park Station
# 53     E                           Expo / Sepulveda Station
# 54     E                               Expo / Bundy Station
# 55     E                     26th Street / Bergamot Station
# 56     E                          17th Street / SMC Station
# 57     E                      Downtown Santa Monica Station
# 58     E                                   Atlantic Station
# 59     E                       East LA Civic Center Station
# 60     E                                  Maravilla Station
# 61     E                                    Indiana Station
# 62     E                                       Soto Station
# 63     E             Mariachi Plaza / Boyle Heights Station
# 64     E                               Pico / Aliso Station
# 65     E               Grand Ave Arts / Bunker Hill Station
# 66     E                          Historic Broadway Station
# 67     E               Little Tokyo / Arts District Station
# 86     E                                       Pico Station
# 87     E  7th Street / Metro Center Station - Metro A & ...
# 109    E               Grand Ave Arts / Bunker Hill Station
# 110    E                          Historic Broadway Station
# 111    E               Little Tokyo / Arts District Station
#
#                         geometry
# 39   POINT (-118.26612 34.04074)
# 40   POINT (-118.25882 34.04861)
# 41    POINT (-118.2736 34.02911)
# 42   POINT (-118.27812 34.02212)
# 43   POINT (-118.28573 34.01823)
# 44   POINT (-118.29154 34.01824)
# 45   POINT (-118.30891 34.01833)
# 46   POINT (-118.33508 34.02253)
# 47    POINT (-118.3461 34.02398)
# 48    POINT (-118.35516 34.0248)
# 49   POINT (-118.37212 34.02636)
# 50    POINT (-118.38899 34.0279)
# 51   POINT (-118.40426 34.02932)
# 52   POINT (-118.42458 34.03682)
# 53   POINT (-118.43423 34.03541)
# 54     POINT (-118.4529 34.0317)
# 55     POINT (-118.46912 34.028)
# 56   POINT (-118.48037 34.02316)
# 57   POINT (-118.49138 34.01401)
# 58    POINT (-118.15447 34.0334)
# 59   POINT (-118.16121 34.03336)
# 60   POINT (-118.16814 34.03332)
# 61    POINT (-118.19218 34.0343)
# 62   POINT (-118.21006 34.04375)
# 63   POINT (-118.21965 34.04722)
# 64   POINT (-118.22594 34.04763)
# 65   POINT (-118.25153 34.05472)
# 66   POINT (-118.24632 34.05216)
# 67   POINT (-118.23876 34.04884)
# 86   POINT (-118.26612 34.04074)
# 87   POINT (-118.25882 34.04861)
# 109  POINT (-118.25153 34.05472)
# 110  POINT (-118.24632 34.05216)
# 111  POINT (-118.23876 34.04884)

# %%
# try it yourself. Query the dataframe for other properties of interest
metroC = metro_trimmed.query("LINE == 'C'")
metroC
# Out:
#    LINE                                            STATION  \
# 16    C                              Redondo Beach Station
# 17    C                                    Douglas Station
# 18    C                                 El Segundo Station
# 19    C                                   Mariposa Station
# 20    C                             Aviation / LAX Station
# 21    C                         Hawthorne / Lennox Station
# 22    C                                   Crenshaw Station
# 23    C                           Vermont / Athens Station
# 24    C                             Harbor Freeway Station
# 25    C                                     Avalon Station
# 26    C  Willowbrook - Rosa Parks Station - Metro Green...
# 27    C                            Long Beach Blvd Station
# 28    C                              Lakewood Blvd Station
# 29    C                                    Norwalk Station
#
#                        geometry
# 16   POINT (-118.3692 33.89464)
# 17   POINT (-118.38311 33.9053)
# 18  POINT (-118.38654 33.91606)
# 19   POINT (-118.38757 33.9232)
# 20  POINT (-118.37713 33.92962)
# 21   POINT (-118.3516 33.93341)
# 22   POINT (-118.32655 33.9252)
# 23  POINT (-118.29173 33.92868)
# 24   POINT (-118.2811 33.92871)
# 25  POINT (-118.26522 33.92746)
# 26  POINT (-118.23805 33.92826)
# 27  POINT (-118.20994 33.92488)
# 28   POINT (-118.1406 33.91307)
# 29  POINT (-118.10472 33.91403)

# %% [markdown]
# ## Plotting
#
# We have now imported a shapefile, trimmed it, and created a series of queried subsets. Let's visualize our data. First, simply pass it the `plot()` command to see what it looks like.

# %%
metro_trimmed.plot()
# Out:
# <Axes: >

# %% [markdown]
# That's great! Very rewarding, with a single command. The reason it is able to plot the station points is because of the `geometry` column that is created from the shapefile. This is a unique geopandas feature.

# %%
metro_trimmed.geometry
# Out:
# 0       POINT (-118.37681 34.1685)
# 1          POINT (-118.3627 34.14)
# 2      POINT (-118.33855 34.10155)
# 3      POINT (-118.32518 34.10163)
# 4      POINT (-118.30812 34.10174)
#                   ...
# 107    POINT (-117.90663 34.13586)
# 108    POINT (-117.89164 34.13681)
# 109    POINT (-118.25153 34.05472)
# 110    POINT (-118.24632 34.05216)
# 111    POINT (-118.23876 34.04884)
# Name: geometry, Length: 112, dtype: geometry

# %% [markdown]
# ### A prettier plot
#
# You can add additional arguments to make the plot prettier: change the size, add legends, etc.

# %%
metro_trimmed.plot(
            figsize=(20,12),   #size of the plot (a bit bigger than the default)
            column = 'LINE',   # column that defines the color of the dots
            legend = True,     # add a legend           
            legend_kwds={
               'loc': 'upper right',
               'bbox_to_anchor':(1,1)
            }                  # this puts the legend to the side
)
# Out:
# <Axes: >

# %% [markdown]
# ## Mapping with folium

# %% [markdown]
# Now it's time for another module. Everybody, please welcome `folium`. Folium brings leaflet, an open source javascript mapping library into our Python environment, allowing you to create instant interactive maps. Try it:

# %%
import folium

# %%
# default folium map
m = folium.Map()
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1fe75d7ec2fd01289c9316d5d784e94 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1fe75d7ec2fd01289c9316d5d784e94&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e1fe75d7ec2fd01289c9316d5d784e94 = L.map(
#                 &quot;map_e1fe75d7ec2fd01289c9316d5d784e94&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc566b6b96c5d6d01d5d77751d8921ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fc566b6b96c5d6d01d5d77751d8921ca.addTo(map_e1fe75d7ec2fd01289c9316d5d784e94);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# A world map is cool... but let's add arguments to the `folium.map` command. Specifically, we can feed it a center latitude value, a center longitude value, and a default zoom level.

# %% [markdown]
# ### Get average lat/lon's

# %%
# average latitude
latitude = metro.LAT.mean()
latitude
# Out:
# np.float64(34.01173607142858)

# %%
# average longitude
longitude = metro.LON.mean()
longitude
# Out:
# np.float64(-118.25569045535715)

# %% [markdown]
# ### Folium map with arguments
#
# Complete the code cell below with arguments to center the map based on the metro coordinates calculated above, and adjust the zoom level accordingly. Refer the [folium documentation](https://python-visualization.github.io/folium/quickstart.html) as necessary.

# %%
# complete this code so that the map will show up 
# centered based on the average lat/lon calculated above
# adjust the zoom level accordingly
m = folium.Map(location=[latitude,longitude])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f21d5ab0a7e2a3a1a42739897804eed0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f21d5ab0a7e2a3a1a42739897804eed0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f21d5ab0a7e2a3a1a42739897804eed0 = L.map(
#                 &quot;map_f21d5ab0a7e2a3a1a42739897804eed0&quot;,
#                 {
#                     center: [34.01173607142858, -118.25569045535715],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e14caf999f73e3d1c984681781ff4c50 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e14caf999f73e3d1c984681781ff4c50.addTo(map_f21d5ab0a7e2a3a1a42739897804eed0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Adding point markers
#
# How do you add a marker to a folium map?
#
# * [Folium quickstart](https://python-visualization.github.io/folium/quickstart.html)
#
# ```
# folium.Marker([45.3288, -121.6625], popup='<i>Mt. Hood Meadows</i>', tooltip=tooltip).add_to(m)
# ```

# %% [markdown]
# Since we want to add a marker *for each station* in our dataframe, we do a for loop, and add the marker within the loop.

# %%
# first, note how to loop through a dataframe:
for index, row in metro.iterrows():
    print(row.STATION, row.LAT, row.LON)
# Out:
# North Hollywood Station 34.168504 -118.376808
# Universal / Studio City Station 34.140002 -118.362699
# Hollywood / Highland Station 34.101547 -118.338549
# Hollywood / Vine Station 34.10163 -118.32518
# Hollywood / Western Station 34.101737 -118.308117
# Vermont / Sunset Station 34.097708 -118.291756
# Vermont / Santa Monica Station 34.08991 -118.29173
# Vermont / Beverly Station 34.076526 -118.291686
# Wilshire / Vermont Station 34.062701 -118.290082
# Westlake / MacArthur Park Station 34.056368 -118.274879
# 7th St / Metro Center Station - Metro Red & Purple Lines 34.048634 -118.258682
# Pershing Square Station 34.049316 -118.251259
# Civic Center / Grand Park Station 34.0549 -118.246057
# Union Station - Metro Red & Purple Lines 34.056197 -118.234249
# Wilshire / Normandie Station 34.061753 -118.301458
# Wilshire / Western Station 34.061689 -118.308756
# Redondo Beach Station 33.89464 -118.369196
# Douglas Station 33.905299 -118.383113
# El Segundo Station 33.916063 -118.386539
# Mariposa Station 33.9232 -118.387572
# Aviation / LAX Station 33.929621 -118.377134
# Hawthorne / Lennox Station 33.933408 -118.351602
# Crenshaw Station 33.925201 -118.32655
# Vermont / Athens Station 33.928683 -118.291733
# Harbor Freeway Station 33.928714 -118.2811
# Avalon Station 33.927465 -118.265217
# Willowbrook - Rosa Parks Station - Metro Green Line 33.928258 -118.238052
# Long Beach Blvd Station 33.92488 -118.209945
# Lakewood Blvd Station 33.91307 -118.1406
# Norwalk Station 33.914033 -118.104717
# Aviation / Century Station 33.945572 -118.378683
# Airport Metro Connector 33.949867 -118.378679
# Westchester / Veterans Station 33.962031 -118.374378
# Downtown Inglewood Station 33.967156 -118.351497
# Fairview Heights Station 33.975252 -118.336072
# Hyde Park Station 33.988187 -118.330816
# Leimert Park Station 34.003909 -118.332016
# Martin Luther King Jr Station 34.009563 -118.335359
# Expo / Crenshaw K-Line Station 34.022156 -118.334851
# Pico Station 34.040735 -118.266118
# 7th Street / Metro Center Station - Metro A & E Lines 34.04861 -118.258822
# LATTC / Ortho Institute Station 34.029112 -118.273603
# Jefferson / USC Station 34.022123 -118.278118
# Expo Park / USC Station 34.018227 -118.285734
# Expo / Vermont Station 34.018245 -118.29154
# Expo / Western Station 34.018331 -118.30891
# Expo / Crenshaw E-Line Station 34.022526 -118.335078
# Farmdale Station 34.023981 -118.346095
# Expo / La Brea / Ethel Bradley Station 34.024803 -118.355159
# La Cienega / Jefferson Station 34.026355 -118.37212
# Culver City Station 34.027896 -118.388986
# Palms Station 34.029323 -118.404255
# Westwood / Rancho Park Station 34.036816 -118.424576
# Expo / Sepulveda Station 34.035408 -118.434234
# Expo / Bundy Station 34.031705 -118.452896
# 26th Street / Bergamot Station 34.027995 -118.46912
# 17th Street / SMC Station 34.023155 -118.480372
# Downtown Santa Monica Station 34.01401 -118.491384
# Atlantic Station 34.033398 -118.154469
# East LA Civic Center Station 34.033364 -118.161206
# Maravilla Station 34.033319 -118.16814
# Indiana Station 34.0343 -118.192182
# Soto Station 34.043747 -118.210061
# Mariachi Plaza / Boyle Heights Station 34.047215 -118.219648
# Pico / Aliso Station 34.047634 -118.22594
# Grand Ave Arts / Bunker Hill Station 34.054724 -118.251531
# Historic Broadway Station 34.052156 -118.246321
# Little Tokyo / Arts District Station 34.048845 -118.238757
# Downtown Long Beach Station 33.768071 -118.192921
# Pacific Ave Station 33.772258 -118.1937
# Anaheim Street Station 33.78183 -118.189384
# Pacific Coast Hwy Station 33.78909 -118.189382
# Willow Street Station 33.807079 -118.189834
# Wardlow Station 33.819865 -118.19609
# Del Amo Station 33.848222 -118.211017
# Artesia Station 33.876082 -118.222503
# Compton Station 33.89749 -118.224249
# Willowbrook - Rosa Parks Station - Metro A-Line 33.928048 -118.237555
# 103rd Street / Watts Towers  Station 33.94222 -118.243159
# Firestone Station 33.959611 -118.243205
# Florence Station 33.97374 -118.243271
# Slauson Station 33.98876 -118.243398
# Vernon Station 34.00292 -118.243303
# Washington Station 34.01965 -118.243084
# San Pedro Street Station 34.026807 -118.255505
# Grand / LATTC Station 34.033155 -118.269333
# Pico Station 34.040735 -118.266118
# 7th Street / Metro Center Station - Metro A & E Lines 34.04861 -118.258822
# 1st Street Station 33.76874 -118.189362
# 5th Street Station 33.773598 -118.189412
# Union Station - Metro A-Line 34.056061 -118.234759
# Chinatown Station 34.063861 -118.23584
# Lincoln Heights / Cypress Park Station 34.080949 -118.220429
# Heritage Square / Arroyo Station 34.087227 -118.213213
# Southwest Museum Station 34.098243 -118.206712
# Highland Park Station 34.111179 -118.192606
# South Pasadena Station 34.115186 -118.157886
# Fillmore Station 34.133521 -118.148126
# Del Mar Station 34.14191 -118.148214
# Memorial Park Station 34.148356 -118.147512
# Lake Station 34.151806 -118.13139
# Allen Station 34.152417 -118.114348
# Sierra Madre Villa Station 34.147752 -118.081212
# Arcadia Station 34.14286 -118.029199
# Monrovia Station 34.133155 -118.003473
# Duarte / City of Hope Station 34.132518 -117.96768
# Irwindale Station 34.129048 -117.932506
# Azusa Downtown Station 34.135863 -117.906631
# APU / Citrus College Station 34.136814 -117.891636
# Grand Ave Arts / Bunker Hill Station 34.054724 -118.251531
# Historic Broadway Station 34.052156 -118.246321
# Little Tokyo / Arts District Station 34.048845 -118.238757

# %% [markdown]
# Using the for loop logic above, create a folium marker for each row in the dataframe.

# %%
for index, row in metro.iterrows():
    # add folium marker code
    folium.Marker([row.LAT, row.LON], popup=row.STATION, tooltip=row.STATION).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f21d5ab0a7e2a3a1a42739897804eed0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f21d5ab0a7e2a3a1a42739897804eed0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f21d5ab0a7e2a3a1a42739897804eed0 = L.map(
#                 &quot;map_f21d5ab0a7e2a3a1a42739897804eed0&quot;,
#                 {
#                     center: [34.01173607142858, -118.25569045535715],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e14caf999f73e3d1c984681781ff4c50 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e14caf999f73e3d1c984681781ff4c50.addTo(map_f21d5ab0a7e2a3a1a42739897804eed0);
#
#
#             tile_layer_e14caf999f73e3d1c984681781ff4c50.addTo(map_f21d5ab0a7e2a3a1a42739897804eed0);
#
#
#             var marker_f353909ed004e1d4c9c8d9c404489e01 = L.marker(
#                 [34.168504, -118.376808],
#                 {
# }
#             ).addTo(map_f21d5ab0a7e2a3a1a42739897804eed0);
#
#
#         var popup_6b7792bcbd7e458a88e1194962a0dde7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe5d734b19ccec1d3373810347bcd1bd = $(`&lt;div id=&quot;html_fe5d734b19ccec1d3373810347bcd1bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;North Hollywood Station&lt;/div&gt;`)[0];
#                 popup_6b7792bcbd7e458a88e1194962a0dde7.setContent(html_fe5d734b19ccec1d3373810347bcd1bd);
#
#
#
#         marker_f353909ed004e1d4c9c8d9c404489e01.bindPopup(popup_6b7792bcbd7e458a88e1194962a0dde7)
#         ;
#
#
#
#
#             marker_f353909ed004e1d4c9c8d9c404489e01.bindTooltip(
#                 `&lt;div&gt;
#                      North Hollywood Station
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_1240d7158f3e2599c494aba0c3a5d4d3 = L.marker(
#                 [34.140002, -118.362699],
#                 {
# }
#             ).addTo(map_f21d5ab0a7e2a3a1a42739897804eed0);
#
#
#         var popup_240a61eb76b6df4ce8679f6c4b2b8bce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81038f51d971452dfc2091b716478256 = $(`&lt;div id=&quot;html_81038f51d971452dfc2091b716478256&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Universal / Studio City Station&lt;/div&gt;`)[0];
#                 popup_240a61eb76b6df4ce8679f6c4b2b8bce.setContent(html_81038f51d971452dfc2091b716478256);
#
#
#
#         marker_1240d7158f3e2599c494aba0c3a5d4d3.bindPopup(popup_240a61eb76b6df4ce8679f6c4b2b8bce)
#         ;
#
#
#
#
#             marker_1240d7158f3e2599c494aba0c3a5d4d3.bindTooltip(
#                 `&lt;div&gt;
#                      Universal / Studio City Station
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c91a1fc7d98c4645a437b629286c894c = L.marker(
#                 [34.101547, -118.338549],
#                 {
# }
#             ).addTo(map_f21d5ab0a7e2a3a1a42739897804eed0);
#
#
#         var popup_dd672f7488e3ea881860080d56504609 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_821ed40755e38b1c5cdad8fb509dfb22 = $(`&lt;div id=&quot;html_821ed40755e38b1c5cdad8fb509dfb22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hollywood / Highland Station&lt;/div&gt;`)[0];
#                 popup_dd672f7488e3ea881860080d56504609.setContent(html_821ed40755e38b1c5cdad8fb509dfb22);
#
#
#
#         marker_c91a1fc7d98c4645a437b629286c894c.bindPopup(popup_dd672f7488e3ea881860080d56504609)
#         ;
#
#
#
#
#             marker_c91a1fc7d98c4645a437b629286c894c.bindTooltip(
#                 `&lt;div&gt;
#                      Hollywood / Highland Station
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_023ae74d005ba7cbdf08c0baf7c6bea5 = L.marker(
#                 [34.10163, -118.32518],
#                 {
# }
#             ).addTo(map_f21d5ab0a7e2a3a1a42739897804eed0);
#
#
#         var popup_6e90c49aa7b2f6bbb2bc58c69ae4d923 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79cc11c957c388f9f8ee5ebc40da5a2e = $(`&lt;div id=&quot;html_79cc11c957c388f9f8ee5ebc40da5a2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hollywood / Vine Station&lt;/div&gt;`)[0];
#                 popup_6e90c49aa7b2f6bbb2bc58c69ae4d923.setContent(html_79cc11c957c388f9f8ee5ebc40da5a2e);
#
#
#
#         marker_023ae74d005ba7cbdf08c0baf7c6bea5.bindPopup(popup_6e90c49aa7b2f6bbb2bc58c69ae4d923)

# %% [markdown]
# ### Color code markers
# That's great, but can we color code the markers so that they correspond to their metro lines?
#
# To do so:
#
# 1. create a new column `color`
# 1. add a color of choice based on the LINE that each row represents

# %% [markdown]
# #### Color options
# Check out the [folium documentation](https://python-visualization.github.io/folium/latest/reference.html) for color options for markers.

# %%
# add a new column
metro['color'] = ''
metro.head()
# Out:
#   LINE                          STATION        LAT         LON  \
# 0    B          North Hollywood Station  34.168504 -118.376808
# 1    B  Universal / Studio City Station  34.140002 -118.362699
# 2    B     Hollywood / Highland Station  34.101547 -118.338549
# 3    B         Hollywood / Vine Station  34.101630 -118.325180
# 4    B      Hollywood / Western Station  34.101737 -118.308117
#
#                       geometry color
# 0   POINT (-118.37681 34.1685)
# 1      POINT (-118.3627 34.14)
# 2  POINT (-118.33855 34.10155)
# 3  POINT (-118.32518 34.10163)
# 4  POINT (-118.30812 34.10174)

# %%
metro.head()
# Out:
#   LINE                          STATION        LAT         LON  \
# 0    B          North Hollywood Station  34.168504 -118.376808
# 1    B  Universal / Studio City Station  34.140002 -118.362699
# 2    B     Hollywood / Highland Station  34.101547 -118.338549
# 3    B         Hollywood / Vine Station  34.101630 -118.325180
# 4    B      Hollywood / Western Station  34.101737 -118.308117
#
#                       geometry color
# 0   POINT (-118.37681 34.1685)
# 1      POINT (-118.3627 34.14)
# 2  POINT (-118.33855 34.10155)
# 3  POINT (-118.32518 34.10163)
# 4  POINT (-118.30812 34.10174)

# %% [markdown]
# ### Find unique values in a column

# %%
# find unique values in the LINE column
metro_trimmed.LINE.unique()
# Out:
# array(['B', 'B/D', 'D', 'C', 'K', 'E', 'A'], dtype=object)

# %% [markdown]
# ### Update column based on a query on another column
# We now want to populate the newly created `color` column with values based on the LINE.
#
# Remember how you used the `loc` command to query the data.

# %%
# display rows that match a query
metro.loc[metro['LINE'] == 'E']
# Out:
#     LINE                                            STATION        LAT  \
# 39     E                                       Pico Station  34.040735
# 40     E  7th Street / Metro Center Station - Metro A & ...  34.048610
# 41     E                    LATTC / Ortho Institute Station  34.029112
# 42     E                            Jefferson / USC Station  34.022123
# 43     E                            Expo Park / USC Station  34.018227
# 44     E                             Expo / Vermont Station  34.018245
# 45     E                             Expo / Western Station  34.018331
# 46     E                     Expo / Crenshaw E-Line Station  34.022526
# 47     E                                   Farmdale Station  34.023981
# 48     E             Expo / La Brea / Ethel Bradley Station  34.024803
# 49     E                     La Cienega / Jefferson Station  34.026355
# 50     E                                Culver City Station  34.027896
# 51     E                                      Palms Station  34.029323
# 52     E                     Westwood / Rancho Park Station  34.036816
# 53     E                           Expo / Sepulveda Station  34.035408
# 54     E                               Expo / Bundy Station  34.031705
# 55     E                     26th Street / Bergamot Station  34.027995
# 56     E                          17th Street / SMC Station  34.023155
# 57     E                      Downtown Santa Monica Station  34.014010
# 58     E                                   Atlantic Station  34.033398
# 59     E                       East LA Civic Center Station  34.033364
# 60     E                                  Maravilla Station  34.033319
# 61     E                                    Indiana Station  34.034300
# 62     E                                       Soto Station  34.043747
# 63     E             Mariachi Plaza / Boyle Heights Station  34.047215
# 64     E                               Pico / Aliso Station  34.047634
# 65     E               Grand Ave Arts / Bunker Hill Station  34.054724
# 66     E                          Historic Broadway Station  34.052156
# 67     E               Little Tokyo / Arts District Station  34.048845
# 86     E                                       Pico Station  34.040735
# 87     E  7th Street / Metro Center Station - Metro A & ...  34.048610
# 109    E               Grand Ave Arts / Bunker Hill Station  34.054724
# 110    E                          Historic Broadway Station  34.052156
# 111    E               Little Tokyo / Arts District Station  34.048845
#
#             LON                     geometry color
# 39  -118.266118  POINT (-118.26612 34.04074)
# 40  -118.258822  POINT (-118.25882 34.04861)
# 41  -118.273603   POINT (-118.2736 34.02911)
# 42  -118.278118  POINT (-118.27812 34.02212)
# 43  -118.285734  POINT (-118.28573 34.01823)
# 44  -118.291540  POINT (-118.29154 34.01824)
# 45  -118.308910  POINT (-118.30891 34.01833)
# 46  -118.335078  POINT (-118.33508 34.02253)
# 47  -118.346095   POINT (-118.3461 34.02398)
# 48  -118.355159   POINT (-118.35516 34.0248)
# 49  -118.372120  POINT (-118.37212 34.02636)
# 50  -118.388986   POINT (-118.38899 34.0279)
# 51  -118.404255  POINT (-118.40426 34.02932)
# 52  -118.424576  POINT (-118.42458 34.03682)
# 53  -118.434234  POINT (-118.43423 34.03541)
# 54  -118.452896    POINT (-118.4529 34.0317)
# 55  -118.469120    POINT (-118.46912 34.028)
# 56  -118.480372  POINT (-118.48037 34.02316)
# 57  -118.491384  POINT (-118.49138 34.01401)
# 58  -118.154469   POINT (-118.15447 34.0334)
# 59  -118.161206  POINT (-118.16121 34.03336)
# 60  -118.168140  POINT (-118.16814 34.03332)
# 61  -118.192182   POINT (-118.19218 34.0343)
# 62  -118.210061  POINT (-118.21006 34.04375)
# 63  -118.219648  POINT (-118.21965 34.04722)
# 64  -118.225940  POINT (-118.22594 34.04763)
# 65  -118.251531  POINT (-118.25153 34.05472)
# 66  -118.246321  POINT (-118.24632 34.05216)
# 67  -118.238757  POINT (-118.23876 34.04884)
# 86  -118.266118  POINT (-118.26612 34.04074)
# 87  -118.258822  POINT (-118.25882 34.04861)
# 109 -118.251531  POINT (-118.25153 34.05472)
# 110 -118.246321  POINT (-118.24632 34.05216)
# 111 -118.238757  POINT (-118.23876 34.04884)

# %% [markdown]
# The `loc` command has additional functionalities. You can use it to update a field based on a query on *another* field. But first, note that folium accepts only a few named colors, according to their [documentation](https://python-visualization.github.io/folium/modules.html):
#
# ```
# [‘red’, ‘blue’, ‘green’, ‘purple’, ‘orange’, ‘darkred’,’lightred’, ‘beige’, ‘darkblue’, ‘darkgreen’, ‘cadetblue’, ‘darkpurple’, ‘white’, ‘pink’, ‘lightblue’, ‘lightgreen’, ‘gray’, ‘black’, ‘lightgray’]
# ```

# %% [markdown]
# Using the `loc` command, we can update the color column for a single LINE:
# ![image.png](attachment:image.png)

# %%
metro.loc[metro['LINE'] == 'E', 'color'] = 'yellow'

# %%
# check your work
metro.loc[metro['LINE'] == 'E']
# Out:
#     LINE                                            STATION        LAT  \
# 39     E                                       Pico Station  34.040735
# 40     E  7th Street / Metro Center Station - Metro A & ...  34.048610
# 41     E                    LATTC / Ortho Institute Station  34.029112
# 42     E                            Jefferson / USC Station  34.022123
# 43     E                            Expo Park / USC Station  34.018227
# 44     E                             Expo / Vermont Station  34.018245
# 45     E                             Expo / Western Station  34.018331
# 46     E                     Expo / Crenshaw E-Line Station  34.022526
# 47     E                                   Farmdale Station  34.023981
# 48     E             Expo / La Brea / Ethel Bradley Station  34.024803
# 49     E                     La Cienega / Jefferson Station  34.026355
# 50     E                                Culver City Station  34.027896
# 51     E                                      Palms Station  34.029323
# 52     E                     Westwood / Rancho Park Station  34.036816
# 53     E                           Expo / Sepulveda Station  34.035408
# 54     E                               Expo / Bundy Station  34.031705
# 55     E                     26th Street / Bergamot Station  34.027995
# 56     E                          17th Street / SMC Station  34.023155
# 57     E                      Downtown Santa Monica Station  34.014010
# 58     E                                   Atlantic Station  34.033398
# 59     E                       East LA Civic Center Station  34.033364
# 60     E                                  Maravilla Station  34.033319
# 61     E                                    Indiana Station  34.034300
# 62     E                                       Soto Station  34.043747
# 63     E             Mariachi Plaza / Boyle Heights Station  34.047215
# 64     E                               Pico / Aliso Station  34.047634
# 65     E               Grand Ave Arts / Bunker Hill Station  34.054724
# 66     E                          Historic Broadway Station  34.052156
# 67     E               Little Tokyo / Arts District Station  34.048845
# 86     E                                       Pico Station  34.040735
# 87     E  7th Street / Metro Center Station - Metro A & ...  34.048610
# 109    E               Grand Ave Arts / Bunker Hill Station  34.054724
# 110    E                          Historic Broadway Station  34.052156
# 111    E               Little Tokyo / Arts District Station  34.048845
#
#             LON                     geometry   color
# 39  -118.266118  POINT (-118.26612 34.04074)  yellow
# 40  -118.258822  POINT (-118.25882 34.04861)  yellow
# 41  -118.273603   POINT (-118.2736 34.02911)  yellow
# 42  -118.278118  POINT (-118.27812 34.02212)  yellow
# 43  -118.285734  POINT (-118.28573 34.01823)  yellow
# 44  -118.291540  POINT (-118.29154 34.01824)  yellow
# 45  -118.308910  POINT (-118.30891 34.01833)  yellow
# 46  -118.335078  POINT (-118.33508 34.02253)  yellow
# 47  -118.346095   POINT (-118.3461 34.02398)  yellow
# 48  -118.355159   POINT (-118.35516 34.0248)  yellow
# 49  -118.372120  POINT (-118.37212 34.02636)  yellow
# 50  -118.388986   POINT (-118.38899 34.0279)  yellow
# 51  -118.404255  POINT (-118.40426 34.02932)  yellow
# 52  -118.424576  POINT (-118.42458 34.03682)  yellow
# 53  -118.434234  POINT (-118.43423 34.03541)  yellow
# 54  -118.452896    POINT (-118.4529 34.0317)  yellow
# 55  -118.469120    POINT (-118.46912 34.028)  yellow
# 56  -118.480372  POINT (-118.48037 34.02316)  yellow
# 57  -118.491384  POINT (-118.49138 34.01401)  yellow
# 58  -118.154469   POINT (-118.15447 34.0334)  yellow
# 59  -118.161206  POINT (-118.16121 34.03336)  yellow
# 60  -118.168140  POINT (-118.16814 34.03332)  yellow
# 61  -118.192182   POINT (-118.19218 34.0343)  yellow
# 62  -118.210061  POINT (-118.21006 34.04375)  yellow
# 63  -118.219648  POINT (-118.21965 34.04722)  yellow
# 64  -118.225940  POINT (-118.22594 34.04763)  yellow
# 65  -118.251531  POINT (-118.25153 34.05472)  yellow
# 66  -118.246321  POINT (-118.24632 34.05216)  yellow
# 67  -118.238757  POINT (-118.23876 34.04884)  yellow
# 86  -118.266118  POINT (-118.26612 34.04074)  yellow
# 87  -118.258822  POINT (-118.25882 34.04861)  yellow
# 109 -118.251531  POINT (-118.25153 34.05472)  yellow
# 110 -118.246321  POINT (-118.24632 34.05216)  yellow
# 111 -118.238757  POINT (-118.23876 34.04884)  yellow

# %% [markdown]
# Now it's your turn. Update the color column for all other metro LINE's in the cell below:

# %%
# Add a color value to each of the following lines: 'A', 'B', 'B/D', 'D', 'C', 'E', 'K'
metro.loc[metro['LINE'] == 'A', 'color'] = 'blue'
metro.loc[metro['LINE'] == 'B', 'color'] = 'red'
metro.loc[metro['LINE'] == 'B/D', 'color'] = 'darkblue'
metro.loc[metro['LINE'] == 'D', 'color'] = 'purple'
metro.loc[metro['LINE'] == 'C', 'color'] = 'green'
metro.loc[metro['LINE'] == 'E', 'color'] = 'orange'
metro.loc[metro['LINE'] == 'K', 'color'] = 'pink'

# %%
metro.sample(20)
# Out:
#     LINE                                   STATION        LAT         LON  \
# 30     K                Aviation / Century Station  33.945572 -118.378683
# 53     E                  Expo / Sepulveda Station  34.035408 -118.434234
# 84     A                  San Pedro Street Station  34.026807 -118.255505
# 100    A                              Lake Station  34.151806 -118.131390
# 6      B            Vermont / Santa Monica Station  34.089910 -118.291730
# 63     E    Mariachi Plaza / Boyle Heights Station  34.047215 -118.219648
# 8    B/D                Wilshire / Vermont Station  34.062701 -118.290082
# 58     E                          Atlantic Station  34.033398 -118.154469
# 61     E                           Indiana Station  34.034300 -118.192182
# 29     C                           Norwalk Station  33.914033 -118.104717
# 39     E                              Pico Station  34.040735 -118.266118
# 94     A                  Southwest Museum Station  34.098243 -118.206712
# 82     A                            Vernon Station  34.002920 -118.243303
# 102    A                Sierra Madre Villa Station  34.147752 -118.081212
# 38     K            Expo / Crenshaw K-Line Station  34.022156 -118.334851
# 78     A      103rd Street / Watts Towers  Station  33.942220 -118.243159
# 13   B/D  Union Station - Metro Red & Purple Lines  34.056197 -118.234249
# 72     A                     Willow Street Station  33.807079 -118.189834
# 25     C                            Avalon Station  33.927465 -118.265217
# 55     E            26th Street / Bergamot Station  34.027995 -118.469120
#
#                         geometry     color
# 30   POINT (-118.37868 33.94557)      pink
# 53   POINT (-118.43423 34.03541)    orange
# 84    POINT (-118.2555 34.02681)      blue
# 100  POINT (-118.13139 34.15181)      blue
# 6    POINT (-118.29173 34.08991)       red
# 63   POINT (-118.21965 34.04722)    orange
# 8     POINT (-118.29008 34.0627)  darkblue
# 58    POINT (-118.15447 34.0334)    orange
# 61    POINT (-118.19218 34.0343)    orange
# 29   POINT (-118.10472 33.91403)     green
# 39   POINT (-118.26612 34.04074)    orange
# 94   POINT (-118.20671 34.09824)      blue
# 82    POINT (-118.2433 34.00292)      blue
# 102  POINT (-118.08121 34.14775)      blue
# 38   POINT (-118.33485 34.02216)      pink
# 78   POINT (-118.24316 33.94222)      blue
# 13    POINT (-118.23425 34.0562)  darkblue
# 72   POINT (-118.18983 33.80708)      blue
# 25   POINT (-118.26522 33.92746)     green
# 55     POINT (-118.46912 34.028)    orange

# %% [markdown]
# ### Add custom tiles (basemap) to folium maps
# Check out the [Tiles documentation](https://python-visualization.github.io/folium/latest/user_guide/raster_layers/tiles.html) for folium to see available tile types. You can also check out [other python notebooks](https://github.com/ivanovitchm/datascience4demography/blob/master/Lesson%2306/Lesson%20%2306%20-%20Folium.ipynb) from open source coders to see how they list out and create map tiles in folium.

# %%
# You can list available tiles from xyzservices.providers
import xyzservices.providers as xyz

# %%
xyz.keys()
# Out:
# dict_keys(['OpenStreetMap', 'MapTilesAPI', 'OpenSeaMap', 'OPNVKarte', 'OpenTopoMap', 'OpenRailwayMap', 'OpenFireMap', 'SafeCast', 'Stadia', 'Thunderforest', 'BaseMapDE', 'CyclOSM', 'Jawg', 'MapBox', 'MapTiler', 'TomTom', 'Esri', 'OpenWeatherMap', 'HERE', 'HEREv3', 'FreeMapSK', 'MtbMap', 'CartoDB', 'HikeBike', 'BasemapAT', 'nlmaps', 'NASAGIBS', 'NLS', 'JusticeMap', 'GeoportailFrance', 'OneMapSG', 'USGS', 'WaymarkedTrails', 'OpenAIP', 'OpenSnowMap', 'AzureMaps', 'SwissFederalGeoportal', 'TopPlusOpen', 'Gaode', 'Strava', 'OrdnanceSurvey'])

# %%
# reset the map (you need to do this to erase previous layers)
m = folium.Map(location=[latitude,longitude], tiles='Cartodb Positron', zoom_start=10, attr="Map data © OpenStreetMap contributors")

# %%
# add the stations with color icons
for index, row in metro.iterrows():
    tooltip_text = row.LINE + ' Line: ' + row.STATION
    folium.Marker(
        [row.LAT,row.LON], 
        popup=row.STATION, 
        tooltip=tooltip_text,
        icon=folium.Icon(color=row.color)
    ).add_to(m)

# show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37085446947c692470c8c33820c5436d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37085446947c692470c8c33820c5436d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37085446947c692470c8c33820c5436d = L.map(
#                 &quot;map_37085446947c692470c8c33820c5436d&quot;,
#                 {
#                     center: [34.01173607142858, -118.25569045535715],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b83cfb9f47d525b1380793ea67a0fe4d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map data \u00a9 OpenStreetMap contributors&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b83cfb9f47d525b1380793ea67a0fe4d.addTo(map_37085446947c692470c8c33820c5436d);
#
#
#             var marker_f3d2475451b0260adbc0ac834eb944c4 = L.marker(
#                 [34.168504, -118.376808],
#                 {
# }
#             ).addTo(map_37085446947c692470c8c33820c5436d);
#
#
#             var icon_03ad0572ba8bb8ad3657eb073aacb366 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_f3d2475451b0260adbc0ac834eb944c4.setIcon(icon_03ad0572ba8bb8ad3657eb073aacb366);
#
#
#         var popup_05af560d1cfb8772cf443e12d42d0d94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88847bf2342f43f7bdb33df3ca381981 = $(`&lt;div id=&quot;html_88847bf2342f43f7bdb33df3ca381981&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;North Hollywood Station&lt;/div&gt;`)[0];
#                 popup_05af560d1cfb8772cf443e12d42d0d94.setContent(html_88847bf2342f43f7bdb33df3ca381981);
#
#
#
#         marker_f3d2475451b0260adbc0ac834eb944c4.bindPopup(popup_05af560d1cfb8772cf443e12d42d0d94)
#         ;
#
#
#
#
#             marker_f3d2475451b0260adbc0ac834eb944c4.bindTooltip(
#                 `&lt;div&gt;
#                      B Line: North Hollywood Station
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_81393cad7680d660c75eba59a5588215 = L.marker(
#                 [34.140002, -118.362699],
#                 {
# }
#             ).addTo(map_37085446947c692470c8c33820c5436d);
#
#
#             var icon_583db37db0907dcc787f6e2c20504c4d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_81393cad7680d660c75eba59a5588215.setIcon(icon_583db37db0907dcc787f6e2c20504c4d);
#
#
#         var popup_8ab57f95b31e3efba62eca8b58f70fc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b19e778ccf57ae17ce6b722572368977 = $(`&lt;div id=&quot;html_b19e778ccf57ae17ce6b722572368977&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Universal / Studio City Station&lt;/div&gt;`)[0];
#                 popup_8ab57f95b31e3efba62eca8b58f70fc7.setContent(html_b19e778ccf57ae17ce6b722572368977);
#
#
#
#         marker_81393cad7680d660c75eba59a5588215.bindPopup(popup_8ab57f95b31e3efba62eca8b58f70fc7)
#         ;
#
#
#
#
#             marker_81393cad7680d660c75eba59a5588215.bindTooltip(
#                 `&lt;div&gt;
#                      B Line: Universal / Studio City Station
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_9d84c846891e18536571d77aa9df49b2 = L.marker(
#                 [34.101547, -118.338549],
#                 {
# }
#             ).addTo(map_37085446947c692470c8c33820c5436d);
#
#
#             var icon_4da6b1eb5063fd76e939a7a69a745a76 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_9d84c846891e18536571d77aa9df49b2.setIcon(icon_4da6b1eb5063fd76e939a7a69a745a76);
#
#
#         var popup_2309262d4f0a541f02af5e17b07b0b9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ee5bfe892d4ac2117155207aa597ec5 = $(`&lt;div id=&quot;html_0ee5bfe892d4ac2117155207aa597ec5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hollywood / Highland Station&lt;/div&gt;`)[0];
#                 popup_2309262d4f0a541f02af5e17b07b0b9c.setContent(html_0ee5bfe892d4

# %% [markdown]
# ### Saving your folium map as an HTML file

# %%
# save the interactive maps as an html file
m.save('metro.html')
